# %%
import pandas as pd

# %% [markdown]
# # Intro to the MultiIndex Module

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"])
bigmac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# # Create a MultiIndex on a DataFrame with the set_index Method

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"])
bigmac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.set_index(keys = ["Date", "Country"], inplace =True)   # Now there are 2 indexes. we can define how many indexes we want to.

# As we can see, it's like a PIVOT TABLE in Excel.
# So in learning, we should try to take the one with the least of values, and put it first. ( It's like an aggregator)
#So if i am going to have a MULTIINDEX which of my columns should I put in the outermost layer Vs. the innermost layer.
# The genral best practice is to take the column with the least number of UNIQUE values and put it on the most outer lvl
# and continue that realtionship as I proceed downwards.

# %%
bigmac.sort_index(inplace = True )   # Sorting the INDEX, first it sort the DATE (which is first in line) and then COUNTRY (second).
bigmac
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# # Extract Index Level Values with the get_level_values Method

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace =True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index   # Here we can see the index, as the multiIndex. we can see a list
               # of a few argument (our 2 indexes)
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.get_level_values(0)#With get_level_values(Numberofindex / name of index)
                                # we can see all the values, within it's index number / Name
bigmac.index.get_level_values("Date")
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values(1)  
bigmac.index.get_level_values("Country")
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# # Change Index Level Name with the set_names Method

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace =True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
# In order to set a new name fgor the index label, we will use set_names() method.

bigmac.index.set_names(names = ["Day", "Location"],inplace =True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
# For another excrise, let's change back the Day index (previously "Date")
# to "Date", but now we will do it just on that column:
bigmac.index.set_names(names = "Date", level = 0, inplace = True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %% [markdown]
# # The sort_index Method on a MultiIndex DataFrame

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index(ascending = False)  # Rearranging in descnding order.
# In the next code we will see how to set an order in multiindex in diffrent orders.
# The first column (Date) will be in ascending order, the second (Country) will be in descnding
bigmac.sort_index(ascending = [True, False])
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83
# ...                                       ...
# 2016-01-01 Brazil                        3.35
#            Belgium                       4.25
#            Austria                       3.76
#            Australia                     3.74
#            Argentina                     2.39
#
# [652 rows x 1 columns]

# %%
# Another way to sort index is with the argument of level.
# if we decided to sort only one index column, we use this syntax:
bigmac.sort_index(level = 1)  # We can see that the output is sorted by country column.
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16
# ...                                   ...
# 2014-01-01 Vietnam                   2.84
# 2014-07-01 Vietnam                   2.83
# 2015-01-01 Vietnam                   2.81
# 2015-07-01 Vietnam                   2.75
# 2016-01-01 Vietnam                   2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# # Extract Rows from a MultiIndex DataFrame

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace =True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
# Extraction of multiIndex is a bit different from what we learn earlier in this course.
# The proper way to do that is like in the syntax below:
bigmac.loc[("2010-01-01", "Argentina"), ["Price in US Dollars"]]

# So, for summary, because multiIndex are made of 2 or more columns, we need to define 
# the ROWS in which we want to extract in a parenthsis, and next in square brackets the COLUMN
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84

# %%
# Using iloc accessor:
bigmac.iloc[0]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.iloc[[10,20,340]]
# Out:
#                      Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                  5.99
#            Malaysia                 2.08
# 2013-07-01 Japan                    3.20

# %% [markdown]
# # The transpose Method on a MultiIndex DataFrame

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace =True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.transpose()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac = bigmac.transpose()
bigmac.loc[("Price in US Dollars",), ("2010-01-01", "Sri Lanka")]
# Out:
# Date                2010-01-01
# Country              Sri Lanka
# Price in US Dollars       1.83

# %% [markdown]
# # The .swaplevel() Method

# %%
bigmac = pd.read_csv("bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace =True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.swaplevel()   # IF we have 2 indexes as multiindexes, there is no need to define 
                     # something in the (). pandas will undestand to swipe between the 2 of them
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
# Lets assume we have 3 multiindexes. in the () we need to spacify just 2 index (No matter
# which one first because it will just swipe them)

bigmac.swaplevel(0,1)
bigmac.swaplevel(1,0)

bigmac.swaplevel("Date","Country")
bigmac.swaplevel("Country", "Date")

# The code above will do the same.
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# # The .stack() Method

# %%
world = pd.read_csv("worldstats.csv", index_col = ["country", "year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
world.stack()  # stack function make the columns as rows, which means it will make the lines (rows) bigger
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
world.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# #  The .unstack() Method, Part 1

# %%
# unstacked function do the oppsite of stack. which means it take the most inner ROWS
# and transfer them into columns.
# We can call unstack as many times as the dataframe stack, until there is no rows. (It's erase the multiIndex)
s = world.stack()
s.unstack()  # The Population and GDP returned into a column.
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack().unstack() # Will take the year and put it as a column
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %% [markdown]
# # The .unstack() Method, Part 2

# %%
world = pd.read_csv("worldstats.csv", index_col = ["country", "year"])
world.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %%
s= world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(level = 0)  #Here it will take the index position of 0 (=country) and move it to the columns.
                      # At the default stat (.unstack()) its will take the last index (the most inner index)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %% [markdown]
# # The .unstack() Method, Part 3

# %%
world = pd.read_csv("worldstats.csv", index_col = ["country", "year"])
s = world.stack()
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(level = ["country", "year"])   # unstack more than 1 row using square brackets []
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack("year",fill_value = "NONE")  # fill value atgument let us to put anything in place of nulls values.
# Out:
# year                           1960         1961         1962         1963  \
# country
# Afghanistan Population  8.99479e+06  9.16494e+06  9.34377e+06  9.53156e+06
#             GDP         5.37778e+08  5.48889e+08  5.46667e+08  7.51111e+08
# Albania     Population         NONE         NONE         NONE         NONE
#             GDP                NONE         NONE         NONE         NONE
# Algeria     Population  1.11249e+07  1.14049e+07  1.16902e+07  1.19851e+07
# ...                             ...          ...          ...          ...
# Yemen, Rep. GDP                NONE         NONE         NONE         NONE
# Zambia      Population  3.04959e+06  3.14285e+06  3.24066e+06  3.34289e+06
#             GDP          6.9874e+08   6.8236e+08   6.7928e+08   7.0434e+08
# Zimbabwe    Population  3.75239e+06  3.87664e+06  4.00626e+06   4.1408e+06
#             GDP         1.05299e+09  1.09665e+09   1.1176e+09  1.15951e+09
#
# ...

# %% [markdown]
# # The pivot Method

# %%
sales = pd.read_csv("salesmen.csv", parse_dates = ["Date"])
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales["Salesman"].value_counts()   # we have a lot of lines, but only 5 salesmen. 
                                   # convert to catagory.
# Out:
# Dave      366
# Oscar     366
# Jeb       366
# Bob       366
# Ronald    366
# Name: Salesman, dtype: int64

# %%
sales = pd.read_csv("salesmen.csv", parse_dates = ["Date"])
sales["Salesman"] = sales["Salesman"].astype("category")
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot(index = "Date", columns = "Salesman", values = "Revenue")

#as we can see in the output we made a pivot, using Dates as index
# Salesman as agregator (columns) and the values of revenue.
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
salesman_pivot = sales.pivot(index = "Salesman", columns = "Date", values = "Revenue")
salesman_pivot.sort_index(axis = 0, ascending =False)
# Out:
# Date      2016-01-01  2016-01-02  2016-01-03  2016-01-04  2016-01-05  \
# Salesman
# Ronald          2639        4951        2703        4258        7771
# Oscar           5250        8661        7075        2524        2793
# Jeb             4430        8026        5188        3144         938
# Dave            1864        8278        4226        3868        2287
# Bob             7172        6362        5982        7917        7837
#
# Date      2016-01-06  2016-01-07  2016-01-08  2016-01-09  2016-01-10  ...  \
# Salesman                                                              ...
# Ronald          5930        1933        5709        4707        8267  ...
# Oscar           7794        9728        5263        7144        7663  ...
# Jeb             8702        4250        9719        5614         301  ...
# Dave            7859        8597        3092        1794        7105  ...
# Bob             1744         918        9863        8337        7543  ...
#
# ...

# %% [markdown]
# # Use the pivot_table method to create an aggregate summary of a DataFrame

# %%
foods = pd.read_csv("foods.csv")
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "mean")  # aggfunc can be used
                                                                         # in many ways:
                                                                         # sum, min, max etc..
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "sum")
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
foods.pivot_table(values = "Spend", index = "Gender", aggfunc = "max")
# Out:
#         Spend
# Gender
# Female  99.51
# Male    99.87

# %%
foods.pivot_table(values = "Spend", index = "Item", aggfunc = "mean")
# Out:
#                Spend
# Item
# Burger     49.780321
# Burrito    49.228810
# Chalupa    52.003537
# Donut      46.838289
# Ice Cream  50.494261
# Sushi      52.668253

# %%
# We can use MultiIndex here by addressing a few columns in index
foods.pivot_table(values = "Spend", index = ["Gender","Item"], aggfunc = "sum")
# Out:
#                     Spend
# Gender Item
# Female Burger     4094.30
#        Burrito    4257.82
#        Chalupa    4152.26
#        Donut      4743.00
#        Ice Cream  4032.87
#        Sushi      4683.08
# Male   Burger     3671.43
#        Burrito    4012.62
#        Chalupa    3492.26
#        Donut      4015.76
#        Ice Cream  4854.12
#        Sushi      4059.85

# %%
# Providing column(s) to the DataFrame Pivot Table:
foods.pivot_table(values = "Spend", index = ["Gender","Item"], columns = "City", aggfunc = "sum")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger      1239.04       1639.24   1216.02
#        Burrito      978.95       1458.76   1820.11
#        Chalupa      876.58       1673.33   1602.35
#        Donut       1446.78       1639.26   1656.96
#        Ice Cream   1521.62       1479.22   1032.03
#        Sushi       1480.29       1742.88   1459.91
# Male   Burger      1294.09        938.18   1439.16
#        Burrito     1399.40       1312.93   1300.29
#        Chalupa     1227.77       1114.23   1150.26
#        Donut       1345.27       1249.36   1421.13
#        Ice Cream   1603.63       2191.27   1059.22
#        Sushi       1396.15       1395.88   1267.82

# %%
foods.pivot_table(values = "Spend", index = ["Gender","Item"], columns = ["Frequency","City"], aggfunc = "sum").head(10)
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger      262.67       231.68   144.66   171.86       215.05
#        Burrito     224.45       321.57   195.63   122.74        34.28
#        Chalupa      43.19        23.49    95.70   158.37       289.96
#        Donut       478.10       247.40   124.35   284.53        50.25
#        Ice Cream   262.19       177.69    92.88    92.53        74.51
#        Sushi        81.07       348.53   393.27    93.16        78.71
# Male   Burger      319.46       112.70   197.72   187.29       213.14
#        Burrito     236.21       165.76   276.23   147.54        89.58
#        Chalupa      54.09       274.81   192.64   333.76        90.70
#        Donut       230.00       190.71   129.42   183.73       259.29
#
# Frequency                    Never                          Often  ...  \
# ...

# %%
# Another way to make a piuvot table is to call it from pandas library as shown below: (here we calling to a data set)
pd.pivot_table(data = foods,values = "Spend", index =
               ["Gender","Item"], columns = ["Frequency","City"], aggfunc = "count")
# Out:
# Frequency           Daily                        Monthly               \
# City             New York Philadelphia Stamford New York Philadelphia
# Gender Item
# Female Burger         6.0          3.0      3.0      3.0          4.0
#        Burrito        5.0          6.0      5.0      3.0          2.0
#        Chalupa        1.0          1.0      1.0      2.0          4.0
#        Donut         12.0          4.0      3.0      4.0          1.0
#        Ice Cream      4.0          3.0      2.0      2.0          2.0
#        Sushi          2.0          6.0      7.0      2.0          1.0
# Male   Burger         5.0          3.0      4.0      3.0          3.0
#        Burrito        3.0          4.0      4.0      3.0          3.0
#        Chalupa        2.0          4.0      4.0      5.0          2.0
#        Donut          5.0          4.0      2.0      4.0          5.0
#        Ice Cream      3.0          5.0      1.0      3.0          6.0
# ...

# %% [markdown]
# # Use the pd.melt method to create a narrow dataset from a wide one

# %%
sales = pd.read_csv("quarters.csv")
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales, id_vars = "Salesman")  #Look the diffrence of between the two tables: the regular one and the melted one
# Out:
#    Salesman variable   value
# 0     Boris       Q1  602908
# 1       Bob       Q1   43790
# 2     Tommy       Q1  392668
# 3    Travis       Q1  834663
# 4    Donald       Q1  580935
# 5       Ted       Q1  656644
# 6       Jeb       Q1  486141
# 7     Stacy       Q1  479662
# 8    Morgan       Q1  992673
# 9     Boris       Q2  233879
# 10      Bob       Q2  514863
# 11    Tommy       Q2  113579
# 12   Travis       Q2  266785
# 13   Donald       Q2  411379
# 14      Ted       Q2   70803
# 15      Jeb       Q2  600753
# 16    Stacy       Q2  742806
# 17   Morgan       Q2  879183
# 18    Boris       Q3  354479
# 19      Bob       Q3  297151
# 20    Tommy       Q3  430882
# 21   Travis       Q3  749238
# 22   Donald       Q3  110390
# 23      Ted       Q3  375948
# 24      Jeb       Q3  742716
# 25    Stacy       Q3  770712
# 26   Morgan       Q3   37945
# 27    Boris       Q4   32704
# 28      Bob       Q4  544493
# 29    Tommy       Q4  247231
# 30   Travis       Q4  570524
# ...

# %%
pd.melt(sales, id_vars = "Salesman", var_name = "Quarter", value_name = "Revenue")
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
